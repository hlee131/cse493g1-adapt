# %%
# 2. Install the patched transformers and core deps in editable mode
# !pip install --no-deps -e third-party/transformers-CFG
# !pip install protobuf==3.20.3
# !pip install accelerate peft trl==0.15.2 \
             bitsandbytes xformers==0.0.29.post3 \
             sentencepiece datasets huggingface_hub hf_transfer
# !pip install unsloth
# Out:
# fatal: destination path 'Adapt' already exists and is not an empty directory.
# /content/Adapt

# %%
# mount drive
from google.colab import drive

drive.mount('/content/drive')
